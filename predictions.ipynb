# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import numpy as np

# %%
#load pickle file
# Load the ANN Tranied model
# On hot model 
# scalar model
model=load_model('model.h5')
##load the scaler and encoders
with open('one_hot_encoder.pkl','rb') as file:
    label_encoder_geo=pickle.load(file)
with open('label_encoder_gender.pkl','rb') as file:
    label_encoder_gender=pickle.load(file)
with open('scaler.pkl','rb') as file:
    scaler=pickle.load(file)
# Out:
# WARNING:tensorflow:From d:\Projects 2026\Project ANN\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Example input data
input_data = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
geo_encoder=label_encoder_geo.transform([[input_data['Geography']]]).toarray()
geo_encoded_df = pd.DataFrame(geo_encoder, columns=label_encoder_geo.get_feature_names_out(['Geography']))
geo_encoded_df
# Out:
# d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
input_data=pd.DataFrame([input_data])

# %%
input_data=pd.concat([input_data.reset_index(drop=True),geo_encoded_df],axis=1)

# %%
input_data
# Out:
#    CreditScore Geography  ... Geography_Germany  Geography_Spain
# 0          600    France  ...               0.0              0.0
#
# [1 rows x 13 columns]

# %%
## Encode categorical variables
input_data['Gender']=label_encoder_gender.transform(input_data['Gender'])
input_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 ## Encode categorical variables
# ----> 2 input_data['Gender']=label_encoder_gender.transform(input_data['Gender'])
#       3 input_data
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\preprocessing\_label.py:139, in LabelEncoder.transform(self, y)
#     137 check_is_fitted(self)
#     138 xp, _ = get_namespace(y)
# --> 139 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     140 # transform of empty array is empty array
#     141 if _num_samples(y) == 0:
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\utils\validation.py:1405, in column_or_1d(y, dtype, input_name, warn, device)
#    1362 """Ravel column or 1d numpy array, else raises an error.
#    1363
#    1364 Parameters
#    (...)   1402 array([1, 1])
#    1403 """
#    1404 xp, _ = get_namespace(y)
# -> 1405 y = check_array(
#    1406     y,
#    1407     ensure_2d=False,
#    1408     dtype=dtype,
#    1409     input_name=input_name,
#    1410     ensure_all_finite=False,
#    1411     ensure_min_samples=0,
#    1412 )
#    1414 shape = y.shape
#    1415 if len(shape) == 1:
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\utils\validation.py:1020, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1012     if xp.isdtype(array.dtype, ("real floating", "complex floating")):
#    1013         _assert_all_finite(
#    1014             array,
#    1015             allow_nan=False,
#    (...)   1018             input_name=input_name,
#    1019         )
# -> 1020     array = xp.astype(array, dtype, copy=False)
#    1021 else:
#    1022     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\externals\array_api_compat\numpy\_aliases.py:125, in astype(x, dtype, copy, device)
#     116 def astype(
#     117     x: Array,
#     118     dtype: DType,
#    (...)    122     device: Device | None = None,
#     123 ) -> Array:
#     124     _helpers._check_device(np, device)
# --> 125     return x.astype(dtype=dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Male'

# %%
input_data['Gender']=label_encoder_gender.transform(input_data['Gender'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 input_data['Gender']=label_encoder_gender.transform(input_data['Gender'])
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\preprocessing\_label.py:139, in LabelEncoder.transform(self, y)
#     137 check_is_fitted(self)
#     138 xp, _ = get_namespace(y)
# --> 139 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     140 # transform of empty array is empty array
#     141 if _num_samples(y) == 0:
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\utils\validation.py:1405, in column_or_1d(y, dtype, input_name, warn, device)
#    1362 """Ravel column or 1d numpy array, else raises an error.
#    1363
#    1364 Parameters
#    (...)   1402 array([1, 1])
#    1403 """
#    1404 xp, _ = get_namespace(y)
# -> 1405 y = check_array(
#    1406     y,
#    1407     ensure_2d=False,
#    1408     dtype=dtype,
#    1409     input_name=input_name,
#    1410     ensure_all_finite=False,
#    1411     ensure_min_samples=0,
#    1412 )
#    1414 shape = y.shape
#    1415 if len(shape) == 1:
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\utils\validation.py:1020, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1012     if xp.isdtype(array.dtype, ("real floating", "complex floating")):
#    1013         _assert_all_finite(
#    1014             array,
#    1015             allow_nan=False,
#    (...)   1018             input_name=input_name,
#    1019         )
# -> 1020     array = xp.astype(array, dtype, copy=False)
#    1021 else:
#    1022     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#
# File d:\Projects 2026\Project ANN\venv\Lib\site-packages\sklearn\externals\array_api_compat\numpy\_aliases.py:125, in astype(x, dtype, copy, device)
#     116 def astype(
#     117     x: Array,
#     118     dtype: DType,
#    (...)    122     device: Device | None = None,
#     123 ) -> Array:
#     124     _helpers._check_device(np, device)
# --> 125     return x.astype(dtype=dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Male'
